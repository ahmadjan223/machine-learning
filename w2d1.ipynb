# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadjan223/machine-learning/blob/main/w2d1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('/content/diamonds.csv')

# %%
data = pd.get_dummies(data, columns=['cut','color','clarity'])

# %%
x=data.drop('price', axis=1)
y= data['price']

data.head()
# Out:
#    Unnamed: 0  carat  depth  table  price     x     y     z  cut_Fair  \
# 0           1   0.23   61.5   55.0    326  3.95  3.98  2.43     False
# 1           2   0.21   59.8   61.0    326  3.89  3.84  2.31     False
# 2           3   0.23   56.9   65.0    327  4.05  4.07  2.31     False
# 3           4   0.29   62.4   58.0    334  4.20  4.23  2.63     False
# 4           5   0.31   63.3   58.0    335  4.34  4.35  2.75     False
#
#    cut_Good  ...  color_I  color_J  clarity_I1  clarity_IF  clarity_SI1  \
# 0     False  ...    False    False       False       False        False
# 1     False  ...    False    False       False       False         True
# 2      True  ...    False    False       False       False        False
# 3     False  ...     True    False       False       False        False
# 4      True  ...    False     True       False       False        False
#
#    clarity_SI2  clarity_VS1  clarity_VS2  clarity_VVS1  clarity_VVS2
# ...

# %%
# prompt: create scatter plot for all arguments with price

for column in x:
  print(column)
  plt.figure()
  plt.scatter(x[column], y)
  plt.xlabel(column)
  plt.ylabel('Price')
  plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')

rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse}')

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae}')

r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error (MSE): 1282237.9409818377
# Root Mean Squared Error (RMSE): 1132.359457496531
# Mean Absolute Error (MAE): 737.1353607728868
# R-squared: 0.9193399796988827

# %%
# prompt: generate regression report for it

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Calculate metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print report
print("Regression Report:")
print(f"MSE: {mse}")
print(f"R-squared: {r2}")
print(f"MAE: {mae}")
# Out:
# Regression Report:
# MSE: 1282237.9409818377
# R-squared: 0.9193399796988827
# MAE: 737.1353607728868

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs. Predicted Prices")
plt.show()

# %% [markdown]
# # for boston data

# %%
data2 =pd.read_csv('/content/Boston (1).csv')

# %%
x=data2.drop('MEDV', axis=1)
y= data2['MEDV']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=30)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred = y_test*0.04

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')

rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse}')

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error (MAE): {mae}')

r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# prompt: generate regression report for it

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Calculate metrics
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print report
print("Regression Report:")
print(f"MSE: {mse}")
print(f"R-squared: {r2}")
print(f"MAE: {mae}")
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs. Predicted Prices")
plt.show()
# Out:
# Mean Squared Error (MSE): 540.1707797438423
# Root Mean Squared Error (RMSE): 23.241574381780644
# Mean Absolute Error (MAE): 21.555546798029557
# R-squared: -5.591113230008009
# Regression Report:
# MSE: 540.1707797438423
# R-squared: -5.591113230008009
# MAE: 21.555546798029557
